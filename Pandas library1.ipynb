# %%
import os
import pandas as pd
os.chdir("C:\\Users\\Poori\\Desktop\\Udemy\\A-Z Machine learning Kaggle\\Github\\DataSet")

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#alternative
#df = df.dropna()

# %%
print(len(df))
# Out:
# 183

# %%
#to fill missing values by 0
#df.fillna(0, inplace=True)

# %%
#Alternative
#df=df.fillna(0)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#filtering data
df[df['Age']<30]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 10            33         1       3      Sandstrom, Miss. Marguerite Rut
# 23            33         1       1         Sloper, Mr. William Thompson
# 27            33         0       1       Fortune, Mr. Charles Alexander
# 66            33         1       2         Nye, Mrs. (Elizabeth Ramell)
# 75            333         0       3              Moen, Mr. Sigurd Hansen
# ..           ...       ...     ...                                  ...
# 802          833         1       1  Carter, Master. William Thornton II
# 823          824         1       3                   Moor, Mrs. (Beila)
# 853          854         1       1            Lines, Miss. Mary Conover
# 887          888         1       1         Graham, Miss. Margaret Edith
# 889          890         1       1                Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch      Ticket     Fare        Cabin Embarked
# ...

# %%
df[df['Fare']>100].head()
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 27            28         0       1  Fortune, Mr. Charles Alexander    male
# 88            89         1       1      Fortune, Miss. Mabel Helen  female
# 118          119         0       1        Baxter, Mr. Quigg Edmond    male
# 195          196         1       1            Lurette, Miss. Elise  female
# 215          216         1       1         Newell, Miss. Madeleine  female
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 27   19.0      3      2     19950  263.0000  C23 C25 C27        S
# 88   23.0      3      2     19950  263.0000  C23 C25 C27        S
# 118  24.0      0      1  PC 17558  247.5208      B58 B60        C
# 195  58.0      0      0  PC 17569  146.5208          B80        C
# 215  31.0      1      0     35273  113.2750          D36        C

# %%
df[df['Sex']=="male"]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
#as index is modified after removing data, we can correct it using rest index

# %%
df.reset_index(inplace=True)
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        1            2         1       1
# 1        3            4         1       1
# 2        6            7         0       1
# 3       10           11         1       3
# 4       11           12         1       1
# ..     ...          ...       ...     ...
# 178    871          872         1       1
# 179    872          873         0       1
# 180    879          880         1       1
# 181    887          888         1       1
# 182    889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
del df['index']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 178          872         1       1
# 179          873         0       1
# 180          880         1       1
# 181          888         1       1
# 182          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df.Sex=="male") & (df.Age>=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              7         0       1
# 9             55         0       1
# 10            63         0       1
# 14            93         0       1
# 15            97         0       1
# 18           111         0       1
# 21           125         0       1
# 27           171         0       1
# 28           175         0       1
# 35           210         1       1
# 40           246         0       1
# 43           253         0       1
# 45           263         0       1
# 46           264         0       1
# 65           332         0       1
# 69           340         0       1
# 84           435         0       1
# 86           439         0       1
# 88           450         1       1
# 90           454         1       1
# 91           457         0       1
# 92           461         1       1
# 93           463         0       1
# 97           488         0       1
# 98           493         0       1
# ...

# %%
df.iloc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# PassengerId                      890
# Survived                           1
# Pclass                             1
# Name           Behr, Mr. Karl Howell
# Sex                             male
# Age                               26
# SibSp                              0
# Parch                              0
# Ticket                        111369
# Fare                              30
# Cabin                           C148
# Embarked                           C
# Name: 182, dtype: object

# %%
df.iloc[-1]['Sex']
# Out:
# 'male'

# %%
df.loc[0,'Sex']
# Out:
# 'female'

# %%
df.loc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 0, dtype: object

# %%
df.loc[0:4,'Sex']
# Out:
# 0    female
# 1    female
# 2      male
# 3    female
# 4    female
# Name: Sex, dtype: object
